# %%
from sheaf import FuzzySet, FuzzyRelation
from numpy import array

# %%
x = FuzzySet(['pizza','beer'],[0.1,0.2])
y = FuzzySet(['pizza','beer'],[0.5, 0.9])
z = FuzzySet(['pizza','beer'],[0.8,0.1])

# %%
x.meet(z)
# Out:
# {'pizza': 0.1, 'beer': 0.1}

# %%
x.join(z)
# Out:
# {'pizza': 0.8, 'beer': 0.2}

# %%
r = FuzzyRelation(['pizza','beer'],['filling,thrilling'],array([[0.7,0.5],[0.6,0.9]]))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-75eeefe43e1e> in <module>
# ----> 1 r = FuzzyRelation(['pizza','beer'],['filling,thrilling'],array([[0.7,0.5],[0.6,0.9]]))
#
# ~\OneDrive\Documents\Research\sheaf-model\sheaf.py in __init__(self, obj, attrib, valueMatrix)
#      90             for j in range(0,N):
#      91                 pairs.update({(obj[i],attrib[j]) : (i,j)})
# ---> 92         self.pairs = pairs
#      93         assert ( (len(valueMatrix[:,0]) == M)
#      94         and (len(valueMatrix[0,:]) == N))
#
# AssertionError:
